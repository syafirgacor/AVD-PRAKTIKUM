# %% [markdown]
# # **Judul**

# %% [markdown]
# "Supermarket Sales Dataset"

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Memuat Dataset**

# %%
file = "/content/drive/MyDrive/Praktikum AVD/SuperMarket Analysis.csv"
df = pd.read_csv(file)

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # **Businnes Understanding**

# %% [markdown]
# ## **Businnes Objective**

# %% [markdown]
# Dataset ini merupakan dataset penjualan supermarket (ritel) pada tahun 2016. Dataset ini memiliki 1000 baris dan 17 kolom. Tujuan dari analisis pada dataset ini adalah untuk memahami tren penjualan, perilaku pelanggan, dan kinerja operasional dari ke 3 cabang perusahaan tersebut.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Analisis dataset ini berdasarkan data transaksi dari 3 cabang supermarket yang ada di negara Myanmar tepatnya Yangon, Naypyitaw, dan Mandalay. Terdapat variasi performa penjualan yang berbeda antara ke 3 cabang, namun perusahaan belum memiliki pemetaan yang jelas mengenai faktor utama yang mendorong kepuasan pelanggan dan efisiensi metode pembayaran.

# %% [markdown]
# ## **Analytic Goals And Project Plan**

# %% [markdown]
# Tujuan Analisis Data dalam mengolah dataset ini adalah sebagai berikut:
#
# * Melakukan identifikasi produk dengan pendapatan dan margin kotor tertinggi
# * melakukan segmentasi pelanggan berdasarkan tipe keanggotaan dan gender
# * memetakan tren penjualan harian dan jam sibuk
#
# Perencanaan Proyek dalam mengolah dataset ini adalah sebagai berikut:
#
# * Melakukan Persiapan Data (Data Preparation) untuk mentransformasi data mentah menjadi data yang bersih dan bermakna
# * Mengidentifikasi kondisi, karakteristik, serta
# potensi masalah
# * Melakukan Visualization dengan mengubah data yang komplek menjadi bentuk visual
# * Menyusun dashboard dan membuat laporan
# * Meringkas dan menyimpulkan hasil dari analisis serta visualisasi data yang telah diolah untuk menjadi saran bisnis

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %% [markdown]
# Dataset mencatat transaksi individu dari sebuah jaringan supermarket di Myanmar, dengan atribut detail untuk setiap penjualan.

# %%
file = "/content/drive/MyDrive/Praktikum AVD/SuperMarket Analysis.csv"
df = pd.read_csv(file)

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # **Struktur Data**

# %% [markdown]
# ## **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# 1. Invoice ID: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Pengidentifikasi untuk setiap transaksi
# 2. Branch: Jumlah Baris: 1000 Tipe Data: object Deksripsi: Lokasi dari cabang supermarket (misalnya, Yangon, Naypyitaw, Mandalay).
# 3. City: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Kota tempat cabang supermarket berada
# 4. Customer Type: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Untuk menujukkan apakah pelanggan tersebut adalah pelanggan "Anggota" atau "Biasa"
# 5. Gender: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Jenis kelamin dari pelanggan.
# 6. Product Line: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Kategori dari produk yang dijual (misalnya, Kesehatan & Kecantikan, Aksesori Elektronik, Rumah & Gaya Hidup).
# 7. Unit Price: Jumlah Baris: 1000 Tipe Data: float64 Dekskripsi: Harga per unit produk.
# 8. Quantity: Jumlah Baris: 1000 Tipe Data: int64 Dekskripsi: Jumlah barang yang dibeli.
# 9. Tax 5%: Jumlah Baris: 1000 Tipe Data: float64 Dekskripsi: Jumlah pajak yang dihitung atas transaksi dengan tarif 5%.
# 10. Sales: Jumlah Baris: 1000 Tipe Data: Float64 Dekskripsi: Jumlah total transaksi termasuk pajak.
# 11. Date: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Tanggal transaksi.
# 12. Time: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Waktu transaksi.
# 13. Payment: Jumlah Baris: 1000 Tipe Data: object Dekskripsi: Metode pembayaran yang digunakan (misalnya, Tunai, Dompet elektronik, Kartu kredit).
# 14. COGS: Jumlah Baris: 1000 Tipe Data: float64 Dekskripsi: Biaya barang terjual, yang mewakili biaya bahan baku produk.
# 15. Gross Margin Percentage: Jumlah Baris: 1000 Tipe Data: float64 Dekskripsi: Persentase tetap dari keuntungan untuk setiap penjualan (4,7619%).
# 16. Gross Income: Jumlah Baris: 1000 Tipe Data: float64 Dekskripsi: Keuntungan yang diperoleh dari transaksi tersebut.
# 17. Rating: Jumlah Baris: 1000 Tipe Data: float64 Dekskripsi: Peringkat kepuasan pelanggan (dari 10).

# %% [markdown]
# ## **Statistik Dekskriptif**

# %%
df.describe(include='all')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     849-09-3807   Alex  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           565     571                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %% [markdown]
# 1. Count and Unique (Kelengkapan Data)
#
# Berdasarkan data, total baris nya adalah 1000. maka dapat disimpulkan:
#
# Tidak ada baris data yang hilang
#
# Kesimpulan: Tidak ada kolom yang memiliki baris data yang hilang.
#
# ---
#
# 2. Mean VS Median
#
# Berdasarkan data
#
# * **SALES**
#
# Mean sales (penjualan) adalah 322,96 berarti medianny adalah 253,84 itu menunjukkan distribusi yang positif. Ada beberapa transaksi yang bernilai sangat besar (maks 1042) yang menarik rata-rata ke atas padahal mayoritasnya bernilai kecil yaitu 250
#
# * **RATING**
#
# Meand dari rating adalah 6,97 sedangkan mediannya adalah 7,0 bisa kita lihat nilai mean dan mediannya hampir sama menunjukkan distribusi kepuasan pelanggan cenderung normal di angka 7

# %% [markdown]
# ## **Cek Tipe Data**

# %% [markdown]
# Kita akan mengechek tipe data pada setiap kolom.
#
# dapat dilihat dibawah ini, kolom date dan juga time bertipe `object` yang harus diubah ke tipe data `date`.

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Sales                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# ## **Incosistent Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten. Tetapi berdasarkan analisis bisa kita lihat tidak ada data yang tidak konsisten.

# %% [markdown]
# Berdasarkan hasil pengecekan, dataset ini tidak memiliki inconsistent value.

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Pada tahap ini kita akan melihat apakah terdapat missing values atau data yang hilang.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                          Null Ratio in %
# Invoice ID                           0.0
# Branch                               0.0
# City                                 0.0
# Customer type                        0.0
# Gender                               0.0
# Product line                         0.0
# Unit price                           0.0
# Quantity                             0.0
# Tax 5%                               0.0
# Sales                                0.0
# Date                                 0.0
# Time                                 0.0
# Payment                              0.0
# cogs                                 0.0
# gross margin percentage              0.0
# gross income                         0.0
# Rating                               0.0

# %% [markdown]
# Bisa kita lihat berdasarkan data tidak ada data yang menghilang, maka tidak terdapat missing values di datasheet ini

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat apakah terdapat data yang terduplikat.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Sales, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani.

# %% [markdown]
# ## **Outliers Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                    Persentase Outliers
# Unit price                               0.0
# Quantity                                 0.0
# Tax 5%                                   0.9
# Sales                                    0.9
# cogs                                     0.9
# gross margin percentage                  0.0
# gross income                             0.9
# Rating                                   0.0

# %% [markdown]
# Dapat terlihat pada kolom:
#
# *   **Tax 5%**
# *   **Sales**
# *   **COGS**
# *   **Gross Income**
#
# Sama-sama memiliki persentase 0,9% (dibawah 1%)

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas: Membandingkan total nominal penjualan `Sales` di setiap wilayah pasar `City`.
#
# Tujuan: Mengidentifikasi kota mana yang memberikan kontribusi pendapatan terbesar dan melihat efektivitas penjualan di masing-masing lokasi (Yangon, Naypyitaw, dan Mandalay).
#
# Visualisasi: Bar Chart (Grafik Batang).

# %%
variabel = df.groupby('Product line')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=variabel.index, y=variabel.values, palette='viridis', hue=variabel.index, legend=False)
plt.title('Total Penjualan per Lini Produk')
plt.xlabel('Lini Produk')
plt.ylabel('Total Penjualan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas: Melihat proporsi atau persentase total pendapatan kotor `gross income` berdasarkan wilayah pasar `City` untuk tiga besar.
#
# Tujuan: Mengetahui wilayah (cabang kota) mana yang paling mendominasi kontribusi keuntungan perusahaan secara keseluruhan dan melihat keseimbangan distribusi pendapatan antar wilayah.
#
# Visualisasi: Pie Chart (Grafik Lingkaran).

# %%
variabel = df.groupby('Branch')['gross income'].sum().sort_values(ascending=False)
variabe2 = variabel.head(3)

plt.figure(figsize=(10, 8))
variabe2.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi Pendapatan Kotor per Cabang (3 Teratas)')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas: Melihat persebaran nilai kepuasan pelanggan `rating` dalam rentang 1 hingga 10.
#
# Tujuan: Mengidentifikasi apakah mayoritas pelanggan memberikan nilai yang cenderung tinggi, rendah, atau merata di tengah (normal).
#
# Visualisasi: Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], bins=20, kde=True)
plt.title('Kepuasan Pelanggan')
plt.xlabel('Nilai')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas: Menganalisis tingkat korelasi antara total penjualan `Sales` dan pendapatan kotor `gross income`.
#
# Tujuan: Mengukur kekuatan hubungan antara nilai transaksi dengan keuntungan yang dihasilkan untuk memastikan konsistensi margin keuntungan.
#
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Sales', 'gross income']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Hubungan Sales dan Gross Income')
plt.show()

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Tipe Data**

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Sales                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# ## **Incosistent Values**

# %% [markdown]
# dapat dilihat dibawah ini, kolom `date` dan juga `time` bertipe `object` sehingga membuat tipe data tidak konsisten harus diubah ke tipe data yang bener yaitu `date`.
#
#
# maka kita ubah dengan kode berikut:

# %%
df["Date"] = pd.to_datetime(df["Date"], format="mixed")
df["Date"].head(5)
# Out:
# 0   2019-01-05
# 1   2019-03-08
# 2   2019-03-03
# 3   2019-01-27
# 4   2019-02-08
# Name: Date, dtype: datetime64[ns]

# %%
df["Time"] = pd.to_datetime(df["Time"], format="mixed")
df["Time"].head(5)
# Out:
# 0   2026-02-28 13:08:00
# 1   2026-02-28 10:29:00
# 2   2026-02-28 13:23:00
# 3   2026-02-28 20:33:00
# 4   2026-02-28 10:37:00
# Name: Time, dtype: datetime64[ns]

# %% [markdown]
# selanjutnya kita cek apakah tipe datanya sudah berubah:

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Sales                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %% [markdown]
# okee sudah betul.

# %% [markdown]
# ## **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                          Null Ratio in %
# Invoice ID                           0.0
# Branch                               0.0
# City                                 0.0
# Customer type                        0.0
# Gender                               0.0
# Product line                         0.0
# Unit price                           0.0
# Quantity                             0.0
# Tax 5%                               0.0
# Sales                                0.0
# Date                                 0.0
# Time                                 0.0
# Payment                              0.0
# cogs                                 0.0
# gross margin percentage              0.0
# gross income                         0.0
# Rating                               0.0

# %% [markdown]
# Berdasarkan hasil pengecekan, dataset ini tidak memiliki missing values atau missing values nya ada di 0% sehingga tidak perlu ada penangganan di bagian ini

# %% [markdown]
# ## **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Sales, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# Berdasarkan hasil pengecekan, di bagian ini juga tidak ditemukan sebuah duplicated values sehingga tidak perlu ada penangganan

# %% [markdown]
# ## **Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                    Persentase Outliers
# Unit price                               0.0
# Quantity                                 0.0
# Tax 5%                                   0.9
# Sales                                    0.9
# cogs                                     0.9
# gross margin percentage                  0.0
# gross income                             0.9
# Rating                                   0.0

# %% [markdown]
# berdasarkan hasil pengecekan, ada 4 data outliers yang perlu penangganan.
#
# Untuk menanggani nya kita akan menggunakan kode berikut:

# %%
columns_to_impute = ["Tax 5%", "Tax 5%"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
columns_to_impute = ["Sales", "Sales"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
columns_to_impute = ["cogs", "cogs"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
columns_to_impute = ["gross income", "gross income"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Setelah kita tanggani kita cek apakah sudah berubah.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                    Persentase Outliers
# Unit price                               0.0
# Quantity                                 0.0
# Tax 5%                                   0.0
# Sales                                    0.0
# cogs                                     0.0
# gross margin percentage                  0.0
# gross income                             0.0
# Rating                                   0.0

# %% [markdown]
# Ok sudah 0% Outliers nya.

# %% [markdown]
# # **Construct data**

# %% [markdown]
# Saya akan membuat kolom Kategorisasi Penjualan (Binning) yang berfungsi untuk yang menentukan tingkat transaksi ke tiga bagian yaitu Low, Medium dan High sesuai dengan tingkat transaksi.

# %%
def kategori_penjualan(sales):
    if sales < 100:
        return 'Low'
    elif 100 <= sales <= 500:
        return 'Medium'
    else:
        return 'High'

df['Sales Category'] = df['Sales'].apply(kategori_penjualan)

# %% [markdown]
# Lanjut kita cek:

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2026-02-28 13:08:00      Ewallet  522.83                 4.761905
# ...

# %% [markdown]
# ok udah mantap.

# %% [markdown]
# # **Data Reduction**

# %% [markdown]
# Menurut saya kolom gross margin percentage dapat kita hapus. Kenapa? Karena jika kita perhatikan rata2 seluruh datanya itu ada di 4,7 persen sekian sehingga kita tidak perlukan.
#
# Untuk menghapusnya kita gunakan kode berikut:

# %%
df = df.drop('gross margin percentage', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-242/2928526227.py in <cell line: 0>()
# ----> 1 df = df.drop('gross margin percentage', axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %% [markdown]
# Kita cek apakah sudah hilang kolom tersebut:

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#                  Time      Payment    cogs  gross income  Rating  \
# 0 2026-02-28 13:08:00      Ewallet  522.83       26.1415     9.1
# ...

# %% [markdown]
# ok hilang mantap.
